# %%
import cv2
import numpy as np
import faiss
import pickle
import requests
import os
import torch
from sentence_transformers import SentenceTransformer
import pandas as pd
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %%
# !pip install faiss-gpu
# Out:
# Collecting faiss-gpu
#   Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (85.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 7.6 MB/s eta 0:00:00
# Installing collected packages: faiss-gpu
# Successfully installed faiss-gpu-1.7.2

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
model = SentenceTransformer('all-MiniLM-L6-v2').to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
product_df = pd.read_csv('Amazon-Products.csv')
product_name = product_df['name']

# %%
product_name = product_name.str.replace('''[^\w\d\s]''','',regex=True).str.lower()
product_name = product_name.drop_duplicates()
product_name = product_name.str.lower()
product_name = product_name.tolist()

# %%
batch_size = 1000
embedding_file = "/content/drive/EcommerceModel/embeddings.npy"

# Generate embeddings in batches and save them
all_embeddings = []
for i in range(0, len(product_name), batch_size):
    batch_texts = product_name[i:i+batch_size]
    batch_embeddings = model.encode(batch_texts, device=device).astype('float32')  # Ensure embeddings are on GPU
    all_embeddings.append(batch_embeddings)

all_embeddings = np.vstack(all_embeddings)

# Load embeddings

# %%
np.save('embeddings.npy', all_embeddings)

# %%
print(len(all_embeddings))
# Out:
# 228428

# %%
all_embeddings = np.load('embeddings.npy')
dimension = all_embeddings.shape[1]

# FAISS-GPU setup
res = faiss.StandardGpuResources()  # Initialize GPU resources
nlist = 100  # Number of clusters
quantizer = faiss.IndexFlatL2(dimension)  # Base quantizer
index = faiss.IndexIVFFlat(quantizer, dimension, nlist, faiss.METRIC_L2)

# Convert to GPU index
gpu_index = faiss.index_cpu_to_gpu(res, 0, index)  # Using GPU ID 0

# Train the index on the embeddings
gpu_index.train(all_embeddings)

# Add embeddings in batches
batch_size = 10000
for i in range(0, all_embeddings.shape[0], batch_size):
    batch_embeddings = all_embeddings[i:i+batch_size]
    gpu_index.add(batch_embeddings)

# Save the index to disk
faiss.write_index(faiss.index_gpu_to_cpu(gpu_index), "large_index.ivf")  # Save a CPU copy of the index

# Reload the index from disk
index = faiss.read_index("large_index.ivf")
gpu_index = faiss.index_cpu_to_gpu(res, 0, index)  # Move it back to GPU

# %%
# Query example
query = "iphone"
query_embedding = model.encode([query], device=device).astype('float32')  # Ensure query embedding is computed on GPU

# Perform similarity search
k = 50  # Top 10 results
distances, indices = gpu_index.search(query_embedding, k)

# Display results
print("Query:", query)
for i in range(k):
    print(f"Result {i+1}:")
    print(f"  Text: {product_name[indices[0][i]]}")
    print(f"  Distance: {distances[0][i]}")
# Out:
# Query: iphone
# Result 1:
#   Text: apple iphone 14 plus 256 gb  blue
#   Distance: 0.8725132942199707
# Result 2:
#   Text: apple iphone 13 256gb  midnight
#   Distance: 0.8844701647758484
# Result 3:
#   Text: apple iphone 13 128gb  midnight
#   Distance: 0.9230003356933594
# Result 4:
#   Text: apple iphone 12 64gb  white
#   Distance: 0.9341724514961243
# Result 5:
#   Text: apple iphone 12 64gb  blue
#   Distance: 0.9800865650177002
# Result 6:
#   Text: apple iphone 12 64gb  black
#   Distance: 0.9819309711456299
# Result 7:
#   Text: apple iphone 14 pro 128 gb  deep purple
#   Distance: 1.002982258796692
# Result 8:
#   Text: apple iphone 13 256gb  blue
#   Distance: 1.0047187805175781
# Result 9:
#   Text: apple iphone 12 128gb  black
#   Distance: 1.0181214809417725
# Result 10:
#   Text: apple iphone 14 128 gb  product red
#   Distance: 1.0184563398361206
# Result 11:
#   Text: apple iphone 13 128gb  blue
#   Distance: 1.0222930908203125
# Result 12:
#   Text: apple iphone 14 pro max 256 gb  deep purple
#   Distance: 1.030189871788025
# Result 13:
#   Text: apple iphone 14 pro max 128 gb  deep purple
#   Distance: 1.0708202123641968
# Result 14:
#   Text: nokia 125 ds
#   Distance: 1.073573112487793
# Result 15:
#   Text: apple iphone 14 128 gb  yellow
#   Distance: 1.075361967086792
# Result 16:
#   Text: apple iphone 14 pro 256 gb  space black
#   Distance: 1.0842907428741455
# Result 17:
#   Text: nothing phone 1 5g black 256 gb 8 gb ram
#   Distance: 1.097217321395874
# Result 18:
#   Text: nothing phone 1 5g white 256 gb 8 gb ram
#   Distance: 1.1054036617279053
# Result 19:
#   Text: apple iphone 12 128gb  green
#   Distance: 1.1138428449630737
# Result 20:
#   Text: apple iphone 14 pro 128 gb  space black
#   Distance: 1.1162055730819702
# Result 21:
#   Text: apple iphone 13 128gb  starlight
#   Distance: 1.1281806230545044
# Result 22:
#   Text: apple iphone 14 pro max 128 gb  space black
#   Distance: 1.1309518814086914
# Result 23:
#   Text: motorola a50 dark blue  dual sim keypad mobile with expandable memory upto 32gb rear camera 1750 mah big battery 6 i
#   Distance: 1.1421968936920166
# Result 24:
#   Text: motorola a50 rose gold  dual sim keypad mobile with expandable memory upto 32gb rear camera 1750 mah big battery 6 i
#   Distance: 1.1509934663772583
# Result 25:
#   Text: blast inn usb otg for iphoneipad compatible with ios 14 and later usb female support connect usb flash drive keyboard
#   Distance: 1.1723992824554443
# Result 26:
#   Text: nokia 3310 dual sim feature phone with mp3 player wireless fm radio and rear camera dark blue
#   Distance: 1.1866589784622192
# Result 27:
#   Text: nokia g11 android 12 smartphone dual sim 3day battery life 4gb ram  64gb storage 50mp dual ai camera  charcoal grey
#   Distance: 1.2021455764770508
# Result 28:
#   Text: nokia g11 android 12 smartphone dual sim 3day battery life 4gb ram  64gb storage 50mp dual ai camera  lake blue
#   Distance: 1.2120747566223145
# Result 29:
#   Text: nokia c12 android 12 go edition smartphone allday battery 4gb ram 2gb ram  2gb virtual ram  64gb capacity  charcoal
#   Distance: 1.2132079601287842
# Result 30:
#   Text: nokia c12 android 12 go edition smartphone allday battery 4gb ram 2gb ram  2gb virtual ram  64gb capacity  light
#   Distance: 1.2138872146606445
# Result 31:
#   Text: philips xenium e209 premium multimedia feature keypad mobile basic bar phone with dual sim card vivid display rear camar
#   Distance: 1.2174512147903442
# Result 32:
#   Text: motorola a70 keypad mobile dual sim with expandable memory upto 32gbcamera 24 inch screen with 1750 mah battery rose gold
#   Distance: 1.2233293056488037
# Result 33:
#   Text: nokia g21 android smartphone dual sim 3day battery life 6gb ram  128gb storage 50mp triple ai camera  dusk
#   Distance: 1.224863052368164
# Result 34:
#   Text: nokia 215 4g dual sim 4g keypad phone with long battery life multiplayer games wireless fm radio and durable ergonomic d
#   Distance: 1.2287811040878296
# Result 35:
#   Text: samsung galaxy tab s8 2794 cm 11 inch display ram 8 gb rom 128 gb expandable s pen inbox wifi tablet graphite
#   Distance: 1.2289773225784302
# Result 36:
#   Text: realme pad wifi4g tablet  3gb ram 32gb rom expandable  264cm 104 inch wuxga display  7100 mah battery  dolby a
#   Distance: 1.232631802558899
# Result 37:
#   Text: nokia c12 android 12 go edition smartphone allday battery 4gb ram 2gb ram  2gb virtual ram  64gb capacity  dark
#   Distance: 1.2335679531097412
# Result 38:
#   Text: realme pad wifi4g tablet  4gb ram 64gb rom expandable  264cm 104 inch wuxga display  7100 mah battery  dolby a
#   Distance: 1.2356363534927368
# Result 39:
#   Text: nokia g21 android smartphone dual sim 3day battery life 6gb ram  128gb storage 50mp triple ai camera  nordic blue
#   Distance: 1.2371095418930054
# Result 40:
#   Text: nokia 6310 dual sim keypad phone with a 28 screen wireless fm radio and rear camera with flash  black
#   Distance: 1.2460805177688599
# Result 41:
#   Text: realme pad wifi tablet  3gb ram 32gb rom expandable  264cm 104 inch wuxga display  7100 mah battery  dolby atmo
#   Distance: 1.2510708570480347
# Result 42:
#   Text: motorola a70 keypad mobile dual sim with expandable memory upto 32gbcamera 24 inch screen with 1750 mah battery dark blue
#   Distance: 1.2545701265335083
# Result 43:
#   Text: nokia 215 4g dual sim 4g phone with long battery life multiplayer games wireless fm radio and durable ergonomic design
#   Distance: 1.2551363706588745
# Result 44:
#   Text: digital picture frame wifi 101 inch ips touch screen highdefinition display digital photo frame 16gb storage easy to u
#   Distance: 1.256793737411499
# Result 45:
#   Text: samsung galaxy tab a7 lite 87 inches slim metal body dolby atmos sound ram 3 gb rom 32 gb expandable wifionly tabl
#   Distance: 1.2572983503341675
# Result 46:
#   Text: realme pad x wifi tablet  4gb ram 64gb rom expandable 279cm 11 inch wuxga display  6nm sd processor  dolby atmos
#   Distance: 1.2579047679901123
# Result 47:
#   Text: nokia 105 single sim pink
#   Distance: 1.2625994682312012
# Result 48:
#   Text: nokia 8210 4g volte keypad phone with dual sim big display inbuilt mp3 player  wireless fm radio  blue
#   Distance: 1.2654883861541748
# Result 49:
#   Text: samsung galaxy a14 5g dark red 4gb 64gb storage  triple rear camera 50 mp main  upto 8 gb ram with ram plus  trav
#   Distance: 1.2672655582427979
# Result 50:
#   Text: nokia 3310 dual sim keypad phone with mp3 player wireless fm radio and rear camera  grey
#   Distance: 1.2703042030334473

# %% [markdown]
# ### TF-IDF

# %%
import cupy as cp
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
from nltk.stem.porter import PorterStemmer
from multiprocessing import Pool
import cupyx.scipy.sparse as cusparse

# %%
product = pd.read_csv('/content/drive/MyDrive/EcommerceData/Amazon-Products.csv')
product_df = product['name'].drop_duplicates()

# %%
print(len(product_df))
# Out:
# 396210

# %%
tmp = product_df.str.replace('''[^\w\d\s]''','',regex=True).str.lower()

# %%
stemmer = PorterStemmer()
def stemming(text):
    return ' '.join([stemmer.stem(word) for word in text.split()])

# %%
product_name = product_name.apply(stemming)

# %%
product.to_csv('/content/drive/MyDrive/EcommerceData/stemming-name.csv',index=False)

# %%
product_name = pd.read_csv('/content/drive/MyDrive/EcommerceData/stemming-name.csv')

# %%
product_name = product_name['name'].tolist()

# %%
print(len(product_name))
# Out:
# 396210

# %%
vectorizer = TfidfVectorizer(max_features=1000,stop_words='english',dtype=np.int8)
tfidf_matrix = vectorizer.fit_transform(product_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:2030: UserWarning: Only (<class 'numpy.float64'>, <class 'numpy.float32'>, <class 'numpy.float16'>) 'dtype' should be used. <class 'numpy.int8'> 'dtype' will be converted to np.float64.
#   warnings.warn(

# %%
print(tfidf_matrix.shape)
# Out:
# (396210, 1000)

# %%
input_text = "iphone"
input_vector = vectorizer.transform([input_text])  # Sparse matrix for input

tfidf_gpu = cusparse.csr_matrix(tfidf_matrix)  # GPU sparse matrix
input_gpu = cusparse.csr_matrix(input_vector)   # GPU sparse matrix for input
print(tfidf_gpu.shape)
print(input_gpu.shape)
# Step 4: Compute cosine similarity
dot_products = tfidf_gpu @ input_gpu.T          # Sparse dot product on GPU
norms = cp.sqrt(tfidf_gpu.multiply(tfidf_gpu).sum(axis=1)) * cp.sqrt(input_gpu.multiply(input_gpu).sum())
print(dot_products.shape)
print(norms.shape)
# Out:
# (396210, 1000)
# (1, 1000)
# (396210, 1)
# (396210, 1)

# %%
# Step 5: Transfer similarities back to CPU
similarities_cpu = dot_products.toarray()
print(similarities_cpu.shape)
print(type(similarities_cpu))
# Step 6: Get top 10 most similar texts
# Out:
# (396210, 1)
# <class 'cupy.ndarray'>

# %%
product_df = product_df.to_frame()
product_df = product_df.reset_index(drop=True) # Reset index to avoid length mismatch
print(len(product_df))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-214-b51675b45e8a> in <cell line: 1>()
# ----> 1 product_df = product_df.to_frame()
#       2 product_df = product_df.reset_index(drop=True) # Reset index to avoid length mismatch
#       3 print(len(product_df))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'to_frame'

# %%
product_df["id"] = similarities_cpu.get()
product_df.head(20)
top_similar_texts = product_df.sort_values(by="id",ascending=False)
top_similar_texts.head(10)
# # Display results
# print("Top Similar Texts:")
# print(top_similar_texts)
# Out:
#                                                      name        id
# 18681   Zapcase Back Case Cover for iPhone 7 / iPhone ...  0.978010
# 13914   POPIO Tempered Glass Compatible for iPhone 6; ...  0.898071
# 18600   Spigen Ultra Hybrid Back Cover Case for iPhone...  0.893437
# 16723   MINDFIED 20W Fast Charger with Cable Compatibl...  0.871093
# 16249   EGOTUDE Ultra Thin Slim Anti Scratch Back Cove...  0.857507
# 323506  Shopnet Wireless Bluetooth Speaker TG113 For i...  0.831352
# 18625   EGOTUDE Dual Layer Hard Back Translucent Hybri...  0.830391
# 13009   Amozo Designed for iPhone 14 / iPhone 13 Cover...  0.754027
# 18097   Belkin 18W USB Type C Adapter (iPhone Fast Cha...  0.744139
# 17300   DR VAKU® 20W iPhone Charger Type C Adapter for...  0.743280

# %%
print(len(similarities_cpu))
# Out:
# 396210

# %%
product_df['name'].str.endswith('...').sum()
# Out:
# 92207

# %%
dense_matrix = cp.asnumpy(tfidf_gpu.toarray())  # Converts GPU matrix to NumPy array

# Step 2: Map names to vectors
name_to_vector = dict(zip(product_df['name'], dense_matrix))

# %%
import pickle

with open("/content/drive/MyDrive/EcommerceData/text-vectors.pkl", "wb") as f:
    pickle.dump(name_to_vector, f)
